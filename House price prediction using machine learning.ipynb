# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 6 from plotly import __version__
#       7 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       8 import plotly.graph_objs as go
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# #Directory and Folder for Data

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# #Download csv file from Kaggle and Inspect

# %%
# Download data from Kaggle https://www.kaggle.com/harlfoxem/housesalesprediction
df = pd.read_csv('kc_house_data.csv')
#df.describe()
#df.info()

df.head(10)
# Out:
#            id             date      price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000   221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000   538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000   180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000   604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000   510000.0  ... -122.045           1800        7503
# 5  7237550310  20140512T000000  1225000.0  ... -122.005           4760      101930
# 6  1321400060  20140627T000000   257500.0  ... -122.327           2238        6819
# 7  2008000270  20150115T000000   291850.0  ... -122.315           1650        9711
# 8  2414600126  20150415T000000   229500.0  ... -122.337           1780        8113
# 9  3793500160  20150312T000000   323000.0  ... -122.031           2390        7570
#
# [10 rows x 21 columns]

# %% [markdown]
# #Check for missing Values

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Descriptive Statistics and then transpose

# %%
df.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21613.0  4.580302e+09  ...  7.308900e+09  9.900000e+09
# price          21613.0  5.400881e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21613.0  3.370842e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21613.0  2.114757e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21613.0  2.079900e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21613.0  1.510697e+04  ...  1.068800e+04  1.651359e+06
# floors         21613.0  1.494309e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21613.0  7.541757e-03  ...  0.000000e+00  1.000000e+00
# view           21613.0  2.343034e-01  ...  0.000000e+00  4.000000e+00
# condition      21613.0  3.409430e+00  ...  4.000000e+00  5.000000e+00
# grade          21613.0  7.656873e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21613.0  1.788391e+03  ...  2.210000e+03  9.410000e+03
# sqft_basement  21613.0  2.915090e+02  ...  5.600000e+02  4.820000e+03
# yr_built       21613.0  1.971005e+03  ...  1.997000e+03  2.015000e+03
# yr_renovated   21613.0  8.440226e+01  ...  0.000000e+00  2.015000e+03
# zipcode        21613.0  9.807794e+04  ...  9.811800e+04  9.819900e+04
# lat            21613.0  4.756005e+01  ...  4.767800e+01  4.777760e+01
# long           21613.0 -1.222139e+02  ... -1.221250e+02 -1.213150e+02
# sqft_living15  21613.0  1.986552e+03  ...  2.360000e+03  6.210000e+03
# sqft_lot15     21613.0  1.276846e+04  ...  1.008300e+04  8.712000e+05
#
# [20 rows x 8 columns]

# %% [markdown]
# #Sort Data by price

# %%
df.sort_values("price")
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 1149   3421079032  20150217T000000  ...           1160       42882
# 15293    40000362  20140506T000000  ...           1700       10387
# 465    8658300340  20140523T000000  ...           1200        7500
# 16198  3028200080  20150324T000000  ...            860        9000
# 8274   3883800011  20141105T000000  ...           1140       11250
# ...           ...              ...  ...            ...         ...
# 1448   8907500070  20150413T000000  ...           4600       21750
# 4411   2470100110  20140804T000000  ...           3560       24345
# 9254   9208900037  20140919T000000  ...           4540       42730
# 3914   9808700762  20140611T000000  ...           3930       25449
# 7252   6762700020  20141013T000000  ...           3940        8800
#
# [21613 rows x 21 columns]

# %%
df.sort_values("price", ascending = False).head(10)
# Out:
#               id             date  ...  sqft_living15  sqft_lot15
# 7252  6762700020  20141013T000000  ...           3940        8800
# 3914  9808700762  20140611T000000  ...           3930       25449
# 9254  9208900037  20140919T000000  ...           4540       42730
# 4411  2470100110  20140804T000000  ...           3560       24345
# 1448  8907500070  20150413T000000  ...           4600       21750
# 1315  7558700030  20150413T000000  ...           4320       24619
# 1164  1247600105  20141020T000000  ...           3430       26788
# 8092  1924059029  20140617T000000  ...           3270       10454
# 2626  7738500731  20140815T000000  ...           3030       23408
# 8638  3835500195  20140618T000000  ...           3720       14592
#
# [10 rows x 21 columns]

# %%
df.sort_values("price", ascending = False).tail(10)
# Out:
#                id             date    price  ...     long  sqft_living15  sqft_lot15
# 10253  2422049104  20140915T000000  85000.0  ... -122.243           1160        7680
# 16714  1322049150  20150305T000000  85000.0  ... -122.236           1160        7405
# 3767   1523049188  20150430T000000  84000.0  ... -122.271           1490       18630
# 18468  7999600180  20140529T000000  83000.0  ... -122.270           2060        6533
# 2141   1623049041  20140508T000000  82500.0  ... -122.296           1572       10570
# 8274   3883800011  20141105T000000  82000.0  ... -122.341           1140       11250
# 16198  3028200080  20150324T000000  81000.0  ... -122.315            860        9000
# 465    8658300340  20140523T000000  80000.0  ... -121.909           1200        7500
# 15293    40000362  20140506T000000  78000.0  ... -122.280           1700       10387
# 1149   3421079032  20150217T000000  75000.0  ... -121.906           1160       42882
#
# [10 rows x 21 columns]

# %% [markdown]
# #Inspect each Column

# %%
for val in df:
   print(df[val].value_counts())
   print()
# Out:
# 795000620     3
# 2206700215    2
# 643300040     2
# 3333002450    2
# 1995200200    2
#              ..
# 3420069065    1
# 7812801125    1
# 4364700875    1
# 3021059276    1
# 1777500160    1
# Name: id, Length: 21436, dtype: int64
#
# 20140623T000000    142
# 20140626T000000    131
# 20140625T000000    131
# 20140708T000000    127
# 20150427T000000    126
#                   ...
# 20150515T000000      1
# 20150524T000000      1
# 20140830T000000      1
# 20140803T000000      1
# 20140517T000000      1
# Name: date, Length: 372, dtype: int64
#
# 450000.0    172
# 350000.0    172
# 550000.0    159
# 500000.0    152
# 425000.0    150
#            ...
# 641500.0      1
# 575950.0      1
# 674250.0      1
# 608700.0      1
# 884744.0      1
# Name: price, Length: 4028, dtype: int64
#
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64
#
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64
#
# 1300    138
# 1400    135
# 1440    133
# 1010    129
# 1660    129
#        ...
# 3001      1
# 4970      1
# 2905      1
# 2793      1
# 1975      1
# Name: sqft_living, Length: 1038, dtype: int64
#
# 5000     358
# 6000     290
# 4000     251
# 7200     220
# 4800     120
#         ...
# 38884      1
# 17313      1
# 35752      1
# 937        1
# 14321      1
# Name: sqft_lot, Length: 9782, dtype: int64
#
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64
#
# 0    21450
# 1      163
# Name: waterfront, dtype: int64
#
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64
#
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64
#
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64
#
# 1300    212
# 1010    210
# 1200    206
# 1220    192
# 1140    184
#        ...
# 2665      1
# 2601      1
# 440       1
# 2473      1
# 1975      1
# Name: sqft_above, Length: 946, dtype: int64
#
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64
#
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64
#
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64
#
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64
#
# 47.5491    17
# 47.6846    17
# 47.6624    17
# 47.5322    17
# 47.6711    16
#            ..
# 47.4686     1
# 47.2495     1
# 47.4237     1
# 47.4142     1
# 47.2715     1
# Name: lat, Length: 5034, dtype: int64
#
# -122.290    116
# -122.300    111
# -122.362    104
# -122.291    100
# -122.372     99
#            ...
# -122.499      1
# -121.792      1
# -122.512      1
# -122.484      1
# -121.893      1
# Name: long, Length: 752, dtype: int64
#
# 1540    197
# 1440    195
# 1560    192
# 1500    181
# 1460    169
#        ...
# 4890      1
# 2873      1
# 952       1
# 3193      1
# 2049      1
# Name: sqft_living15, Length: 777, dtype: int64
#
# 5000      427
# 4000      357
# 6000      289
# 7200      211
# 4800      145
#          ...
# 8989        1
# 871200      1
# 809         1
# 4907        1
# 6147        1
# Name: sqft_lot15, Length: 8689, dtype: int64

# %% [markdown]
# #House Price Distribution

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['price'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# #Living Space Distribution

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['sqft_living'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# #Bedrooms and Bathrooms

# %%
plt.figure(figsize = (10,6))
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize = (12,8))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['bathrooms'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# #Grade

# %%
import pylab as P
df['grade'].hist()
P.show()

# %%
fig = sns.boxplot(x='grade', y='price', data=df)
fig.axis(ymin=0, ymax=5000000);

# %% [markdown]
# #Year Built

# %%
df['yr_built'].hist(bins = 100)
P.show()

# %%
sns.countplot(x='floors',data=df, palette='Set2')

# %% [markdown]
# #Scatter Graph of Price vs Living Space

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x='sqft_living',y='price',data=df)

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x='sqft_lot',y='price',data=df)

# %% [markdown]
# #Waterfront properties come at a premium

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %% [markdown]
# #Latitude and Longitude![CaptureKingsCounty.JPG](data:image/jpeg;base64,...)

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %% [markdown]
# #The Correlation Matrix

# %%
# Finding out the correlation between the features
corr = df.corr()
corr.shape
# Out:
# (20, 20)

# %%
# Plotting the heatmap of correlation between features
plt.figure(figsize=(12,12))
sns.heatmap(corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')

# %% [markdown]
# #Drop some strings

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
dCol = ['id', 'date', 'zipcode']
df.drop(dCol, axis=1, inplace=True)
df.head()
# Out:
#       price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ... -122.257           1340        5650
# 1  538000.0         3       2.25  ... -122.319           1690        7639
# 2  180000.0         2       1.00  ... -122.233           2720        8062
# 3  604000.0         4       3.00  ... -122.393           1360        5000
# 4  510000.0         3       2.00  ... -122.045           1800        7503
#
# [5 rows x 18 columns]

# %% [markdown]
# # Full Sample target variable and independent variables

# %%
# Full Sample target variable and independent variables
X = df.drop(['price'], axis = 1)
y = df['price']

# %% [markdown]
# # Splitting to training and testing data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 4)

# %% [markdown]
# #Linear Regression: Import library

# %%
# Import library for Linear Regression
from sklearn import metrics
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# Create a Linear regressor
lm = LinearRegression()

# Train the model using the training sets
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# #Linear Regression: Model prediction on train data

# %%
# Model prediction on train data
y_pred = lm.predict(X_train)

# %% [markdown]
# ![RMSE.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# [R square and Adjusted R square](https://en.wikipedia.org/wiki/Coefficient_of_determination#Adjusted_R2)

# %% [markdown]
# # Linear Regression: Model Evaluation

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.6974131458149577
# Adjusted R^2: 0.6970727331009648
# MAE: 126513.85785006893
# MSE: 40784715276.39774
# RMSE: 201952.25989425753

# %% [markdown]
# # Linear Regression: Visualizing the differences between actual prices and predicted values

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# #Linear Regression: Inspecting residuals

# %%
# Checking residuals
plt.scatter(y_pred,y_train-y_pred)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# # Linear Regression: Checking Normality of errors

# %%
# Checking Normality of errors
sns.distplot(y_train-y_pred)
plt.title("Histogram of Residuals")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# #Linear Regression: Model evaluation for OLS

# %%
# Predicting Test data with the model
y_test_pred = lm.predict(X_test)

# %%
# Model Evaluation
acc_linreg = metrics.r2_score(y_test, y_test_pred)
print('R^2:', acc_linreg)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.690206436860247
# Adjusted R^2: 0.6893919471334644
# MAE: 126041.42370396323
# MSE: 41739221948.95131
# RMSE: 204301.79135032397

# %% [markdown]
# #Random Forest: Import Random Forest Regressor

# %%
# Import Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regressor
reg = RandomForestRegressor()

# Train the model using the training sets
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# #Random Forest: Model Evaluation

# %%
# Model prediction on train data
y_pred = reg.predict(X_train)

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.981713597093699
# Adjusted R^2: 0.9816930247391621
# MAE: 26517.274269987105
# MSE: 2464765820.615906
# RMSE: 49646.407932658185

# %% [markdown]
# # Random Forest: Visualizing the differences between actual prices and predicted values

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# # Random Forest: Checking residuals

# %%
# Checking residuals
plt.scatter(y_pred,y_train-y_pred)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# # Random Forest: Predicting Test data with the model

# %%
# Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %% [markdown]
# # Random Forest: Model Evaluation

# %%
# Model Evaluation
acc_rf = metrics.r2_score(y_test, y_test_pred)
print('R^2:', acc_rf)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.8620072901352578
# Adjusted R^2: 0.8616444883926502
# MAE: 71030.83646904468
# MSE: 18592085277.715786
# RMSE: 136352.7971026476

# %% [markdown]
# #XGBoost

# %% [markdown]
# #XGBoost: Import XGBoost Regressor

# %%
# Import XGBoost Regressor
from xgboost import XGBRegressor

#Create a XGBoost Regressor
reg = XGBRegressor()

# Train the model using the training sets
reg.fit(X_train, y_train)
# Out:
# [18:18:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %% [markdown]
# #XGBoost: Model Evaluation

# %%
# Model prediction on train data
y_pred = reg.predict(X_train)

# %% [markdown]
# #XGBoost: Model Evaluation

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.8974386841392623
# Adjusted R^2: 0.8973233018105196
# MAE: 74588.29706709796
# MSE: 13823912069.870935
# RMSE: 117575.13372253053

# %% [markdown]
# # XGBost: Visualizing the differences between actual prices and predicted values

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# #XGBoost: Predicting Test data with the model

# %%
#Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %%
# Model Evaluation
acc_xgb = metrics.r2_score(y_test, y_test_pred)
print('R^2:', acc_xgb)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.8665451904229056
# Adjusted R^2: 0.8661943194419575
# MAE: 79237.01129944864
# MSE: 17980683202.835056
# RMSE: 134092.0698730356

# %% [markdown]
# #Models Compared

# %%
models = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest', 'XGBoost'],
    'R-squared Score': [acc_linreg*100, acc_rf*100, acc_xgb*100]})
models.sort_values(by='R-squared Score', ascending=False)
# Out:
#                Model  R-squared Score
# 2            XGBoost        86.654519
# 1      Random Forest        86.177579
# 0  Linear Regression        69.104220
